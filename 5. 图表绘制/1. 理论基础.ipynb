# %%
# -*- coding:utf-8 -*-
import matplotlib.pyplot as plt
from IPython.display import Image

# %% [markdown]
# ## Figure结构

# %% [markdown]
# 首先我们需要知道在matplotlib中一个Figure是由哪些部分组成的，然后就可以对各个不同的组成部分进行自定义。

# %%
Image('./source/anatomy.png')

# %% [markdown]
# 首先实例化一个Figure

# %%
fig = plt.figure()
fig

# %% [markdown]
# 我们作图就是对matplotlib生成的fig实例进行自定义，而要做出想要格式的图表，只需根据目标图表调整各个fig的组件即可。
#
# 为了便于理解各个组件的作用，我们会尽量少用plt的快速指令，而是尽可能调用Image各个组成部分（实例fig, ax, gs等）的绑定后方法（bound method）
